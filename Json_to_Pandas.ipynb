# %%
pandas.read_json('/tracks/tracks2010.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a7119f77f1bf> in <module>
# ----> 1 pandas.read_json('/tracks/tracks2010.txt')
#
# NameError: name 'pandas' is not defined

# %%
import pandas as pd

# %%
track_df = pd.read_json('file://localhost/Users/ark/DataScience/Mod1-Project/tracks/tracks2010.txt')

# %%
trakc_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-782e255b74d5> in <module>
# ----> 1 trakc_df
#
# NameError: name 'trakc_df' is not defined

# %%
track_df
# Out:
#                                                 Lady Gaga  \
# id                                 1HY2Jd0NmPuamShAr6KMms
# tracks  [2VxeLyX666F8uXCJ0dZF8B, 2rbDhOo9Fh61Bbu23T2qC...
#
#                                              Taylor Swift  \
# id                                 06HL4z0CvFAxyc27GXpf02
# tracks  [5sOch9Cf4uxcMtwFzMtNqQ, 55n9yjI6qqXh5F2mYvUc2...
#
#                                                    Eminem  \
# id                                 7dGJo4pcD2V6oG8kP0tJRR
# tracks  [60SdxE8apGAxMiRrpbmLY0, 4xkOaSrkexMciUUogZKVT...
#
#                                           Lady Antebellum  \
# id                                 32WkQRZEVKSzVAAYqukAEA
# tracks  [7GAaTpSoTWUTbP2Yxlt4Hd, 11EX5yhxr9Ihl3IN1asrf...
#
#                                                     Ke$ha  \
# id                                 6LqNN22kT3074XbTVUrhzX
# tracks  [0jdny0dhgjUwoIp5GkqEaA, 0HPD5WQqrq7wPWR7P7Dw1...
#
#                                                     Usher  \
# ...

# %%
track_df = pd.read_json('file://localhost/Users/ark/DataScience/Mod1-Project/tracks/tracks2010.txt', orient='index')

# %%
track_df
# Out:
#                                          id  \
# Lady Gaga            1HY2Jd0NmPuamShAr6KMms
# Taylor Swift         06HL4z0CvFAxyc27GXpf02
# Eminem               7dGJo4pcD2V6oG8kP0tJRR
# Lady Antebellum      32WkQRZEVKSzVAAYqukAEA
# Ke$ha                6LqNN22kT3074XbTVUrhzX
# Usher                23zg3TcAtWQy7J6upgbUnj
# The Black Eyed Peas  1yxSLGMDHlW21z4YXirZDS
# Justin Bieber        1uNFoZAHBGtllmzznpCI3s
# Rihanna              5pKCCKE2ajJHZ9KAiaK11H
# Drake                3TVXtAsR1Inumwj472S9r4
# Katy Perry           6jJ0s89eD6GaHleKKya26X
# Susan Boyle          1qAuetfG6mhtDgsVIffWQc
# Jason Derulo         07YZf4WDAMNwqr4jfgOZ8y
# B.o.B                5ndkK3dpZLKtBklKjxNQwT
# Taio Cruz            6MF9fzBmfXghAz953czmBC
# Train                3FUY2gzHeIiaesXtOAdB7A
# Ludacris             3ipn9JLAPI5GUEo4y4jcoi
# Trey Songz           2iojnBLj0qIMiKPvVhLnsH
# Michael Buble        1GxkXlMwML1oSg5eLPiAz3
# Lil Wayne            55Aa2cqylxrFIXC767Z865
# ...

# %%
track_df['tracks'][0]
# Out:
# ['2VxeLyX666F8uXCJ0dZF8B',
#  '2rbDhOo9Fh61Bbu23T2qCk',
#  '7dZ1Odmx9jWIweQSatnRqo',
#  '3DKpA54hrFIdPN6AtL9HXa',
#  '5IXk9TVBuxG87sFrwclBJw',
#  '0WfKDYeUAoLA3vdvLKKWMW',
#  '6Id5RM56PFn2hB4I0ox0WA',
#  '5P5cGNzqh6A353N3ShDK6Y',
#  '54e5nUP7pHqVfaiCsq9FpW',
#  '378u8gf9qpJ4ZhxHEvrodl']
